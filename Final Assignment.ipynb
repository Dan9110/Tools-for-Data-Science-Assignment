# %% [markdown]
# # __My Jupyter Notebook on IBM Watson Studio__

# %% [markdown]
# #### __Daniel Bejarano__
#
# #### Data Scientist Student

# %% [markdown]
# #### *I am interested in Data Science because I want to change careers. I tried the first Data Science course and I liked it.*

# %% [markdown]
# ### __The following code shows a Matplotlib Histogram__

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.random.normal(170, 10, 250)

plt.hist(x)
plt.show()

# %% [markdown]
# ---
#
#
#
#
#
# >This is an introduction to Matplotlib.
#
# [Matplotlib](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.hist.html)
